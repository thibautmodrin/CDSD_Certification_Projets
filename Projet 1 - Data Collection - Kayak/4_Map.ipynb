# %%
import requests
from io import StringIO
import pandas as pd
import plotly.express as px


response=requests.get('https://tmopenlabbucket.s3.eu-west-3.amazonaws.com/City_Meteo_Rank.csv')
df = pd.read_csv(StringIO(response.text))
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                             city        lat       lon    CCM
# 0                        St Malo  48.649518 -2.026041  0.946
# 1                    La Rochelle  46.159113 -1.152043  0.942
# 2              Mont Saint Michel  48.635954 -1.511460  0.937
# 3                       Le Havre  49.493898  0.107973  0.930
# 4                         Cassis  43.214036  5.539632  0.918
# 5       Saintes Maries de la mer  43.451592  4.427720  0.918
# 6                      Marseille  43.296174  5.369953  0.918
# 7                        Bayonne  43.494514 -1.473666  0.918
# 8                       Biarritz  43.471144 -1.552727  0.915
# 9                  Aigues Mortes  43.566152  4.191540  0.915
# 10                        Bayeux  49.276462 -0.702474  0.900
# 11            Bormes les Mimosas  43.150697  6.341928  0.874
# 12              Gorges du Verdon  43.749656  6.328562  0.861
# 13                         Lille  50.636565  3.063528  0.848
# ...

# %%
fig=px.scatter_mapbox(df,lat='lat',lon='lon',color='CCM',mapbox_style='open-street-map',zoom=5,size='CCM',color_continuous_scale=px.colors.sequential.speed,height=1000
                      )

fig.show()
# Out:
# /tmp/ipykernel_1093254/3530186675.py:1: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig=px.scatter_mapbox(df,lat='lat',lon='lon',color='CCM',mapbox_style='open-street-map',zoom=5,size='CCM',color_continuous_scale=px.colors.sequential.speed,height=1000
