# %%
import requests
from io import StringIO
import pandas as pd
import plotly.express as px


response=requests.get('https://tmopenlabbucket.s3.eu-west-3.amazonaws.com/City_Meteo_Rank.csv')
df = pd.read_csv(StringIO(response.text))
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                             city        lat       lon    CCM
# 0                      Marseille  43.296174  5.369953  0.917
# 1             Bormes les Mimosas  43.150697  6.341928  0.910
# 2                  Aigues Mortes  43.566152  4.191540  0.896
# 3                          Nimes  43.837425  4.360069  0.872
# 4                        Avignon  43.949249  4.805901  0.870
# 5                         Cassis  43.214036  5.539632  0.867
# 6                    Carcassonne  43.213036  2.349107  0.856
# 7                    La Rochelle  46.159113 -1.152043  0.849
# 8                       Biarritz  43.471144 -1.552727  0.847
# 9                Aix en Provence  43.529842  5.447474  0.843
# 10                       Bayonne  43.494514 -1.473666  0.841
# 11                          Uzes  44.012128  4.419672  0.840
# 12      Saintes Maries de la mer  43.451592  4.427720  0.836
# 13                      Toulouse  43.604462  1.444247  0.824
# 14                     Montauban  44.017584  1.354999  0.819
# 15                     Collioure  42.525050  3.083155  0.818
# 16              Gorges du Verdon  43.749656  6.328562  0.781
# 17                      Grenoble  45.187560  5.735782  0.779
# 18                        Colmar  48.077752  7.357964  0.774
# 19                     Eguisheim  48.044797  7.307962  0.773
# 20                    Strasbourg  48.584614  7.750713  0.760
# 21                         Paris  48.858890  2.320041  0.740
# 22                      Besancon  47.238022  6.024362  0.732
# 23             Mont Saint Michel  48.635954 -1.511460  0.719
# 24                       St Malo  48.649518 -2.026041  0.719
# 25                      Le Havre  49.493898  0.107973  0.719
# 26                         Dijon  47.321581  5.041470  0.718
# 27                        Bayeux  49.276462 -0.702474  0.714
# 28                         Rouen  49.440459  1.093966  0.705
# 29                          Lyon  45.757814  4.832011  0.686
# 30                         Lille  50.636565  3.063528  0.684
# 31                        Annecy  45.899235  6.128885  0.683
# 32                        Amiens  49.894171  2.295695  0.679
# 33  Chateau du Haut Koenigsbourg  48.249523  7.345492  0.640

# %%
fig=px.scatter_mapbox(df,lat='lat',lon='lon',color='CCM',mapbox_style='open-street-map',zoom=5,size='CCM',color_continuous_scale=px.colors.sequential.speed,height=1000
                      )

fig.show()
