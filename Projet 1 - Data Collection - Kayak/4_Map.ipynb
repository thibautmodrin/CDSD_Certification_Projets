# %%
import requests
from io import StringIO
import pandas as pd
import plotly.express as px


response=requests.get('https://tmopenlabbucket.s3.eu-west-3.amazonaws.com/City_Meteo_Rank.csv')
df = pd.read_csv(StringIO(response.text))
df.drop(columns=['Unnamed: 0'], inplace=True)
df
# Out:
#                             city        lat       lon    CCM
# 0                       Le Havre  49.493898  0.107973  0.925
# 1                        St Malo  48.649518 -2.026041  0.922
# 2                         Bayeux  49.276462 -0.702474  0.910
# 3       Saintes Maries de la mer  43.451592  4.427720  0.897
# 4                       Biarritz  43.471144 -1.552727  0.886
# 5                        Bayonne  43.494514 -1.473666  0.872
# 6                    La Rochelle  46.159113 -1.152043  0.865
# 7                  Aigues Mortes  43.566152  4.191540  0.856
# 8              Mont Saint Michel  48.635954 -1.511460  0.843
# 9                         Cassis  43.214036  5.539632  0.840
# 10                     Marseille  43.296174  5.369953  0.835
# 11  Chateau du Haut Koenigsbourg  48.249523  7.345492  0.816
# 12              Gorges du Verdon  43.749656  6.328562  0.775
# 13            Bormes les Mimosas  43.150697  6.341928  0.772
# 14                         Lille  50.636565  3.063528  0.753
# 15                        Amiens  49.894171  2.295695  0.741
# 16                    Strasbourg  48.584614  7.750713  0.739
# 17                     Eguisheim  48.044797  7.307962  0.729
# 18                         Rouen  49.440459  1.093966  0.727
# 19                        Colmar  48.077752  7.357964  0.716
# 20                      Besancon  47.238022  6.024362  0.713
# 21                         Paris  48.858890  2.320041  0.699
# 22                        Annecy  45.899235  6.128885  0.681
# 23                     Collioure  42.525050  3.083155  0.659
# 24                         Dijon  47.321581  5.041470  0.625
# 25               Aix en Provence  43.529842  5.447474  0.608
# 26                   Carcassonne  43.213036  2.349107  0.599
# 27                      Grenoble  45.187560  5.735782  0.591
# 28                      Toulouse  43.604462  1.444247  0.577
# 29                          Lyon  45.757814  4.832011  0.557
# 30                          Uzes  44.012128  4.419672  0.557
# 31                     Montauban  44.017584  1.354999  0.556
# 32                         Nimes  43.837425  4.360069  0.553
# 33                       Avignon  43.949249  4.805901  0.550

# %%
fig=px.scatter_mapbox(df,lat='lat',lon='lon',color='CCM',mapbox_style='open-street-map',zoom=5,size='CCM',color_continuous_scale=px.colors.sequential.speed,height=1000
                      )

fig.show()
# Out:
# /tmp/ipykernel_2166314/3530186675.py:1: DeprecationWarning: *scatter_mapbox* is deprecated! Use *scatter_map* instead. Learn more at: https://plotly.com/python/mapbox-to-maplibre/
#   fig=px.scatter_mapbox(df,lat='lat',lon='lon',color='CCM',mapbox_style='open-street-map',zoom=5,size='CCM',color_continuous_scale=px.colors.sequential.speed,height=1000
